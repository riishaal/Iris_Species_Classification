# %%
import numpy as np
import pandas as pd

df=pd.read_csv("/content/Iris.csv")
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isna().sum()  #To know missing value
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df1=df.drop(columns=["Id"],axis=1)  # axis=1 to remove the data in column wise.....#axis=0 to remove data in row wise
print(df1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df1.dtypes  # To know data types
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
x=df1.drop("Species",axis=1).values  #To get input    #values enn kodthaaal...array ayt covert cheyyam
y=df1["Species"].values  #To get output
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
#Testing and training
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 81             5.5           2.4            3.7           1.0
# 133            6.3           2.8            5.1           1.5
# 137            6.4           3.1            5.5           1.8
# 75             6.6           3.0            4.4           1.4
# 109            7.2           3.6            6.1           2.5
# ..             ...           ...            ...           ...
# 71             6.1           2.8            4.0           1.3
# 106            4.9           2.5            4.5           1.7
# 14             5.8           4.0            1.2           0.2
# 92             5.8           2.6            4.0           1.2
# 102            7.1           3.0            5.9           2.1
#
# [105 rows x 4 columns]

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 73             6.1           2.8            4.7           1.2
# 18             5.7           3.8            1.7           0.3
# 118            7.7           2.6            6.9           2.3
# 78             6.0           2.9            4.5           1.5
# 76             6.8           2.8            4.8           1.4
# 31             5.4           3.4            1.5           0.4
# 64             5.6           2.9            3.6           1.3
# 141            6.9           3.1            5.1           2.3
# 68             6.2           2.2            4.5           1.5
# 82             5.8           2.7            3.9           1.2
# 110            6.5           3.2            5.1           2.0
# 12             4.8           3.0            1.4           0.1
# 36             5.5           3.5            1.3           0.2
# 9              4.9           3.1            1.5           0.1
# ...

# %%
y_train
# Out:
# 81     Iris-versicolor
# 133     Iris-virginica
# 137     Iris-virginica
# 75     Iris-versicolor
# 109     Iris-virginica
#             ...
# 71     Iris-versicolor
# 106     Iris-virginica
# 14         Iris-setosa
# 92     Iris-versicolor
# 102     Iris-virginica
# Name: Species, Length: 105, dtype: object

# %%
y_test
# Out:
# 73     Iris-versicolor
# 18         Iris-setosa
# 118     Iris-virginica
# 78     Iris-versicolor
# 76     Iris-versicolor
# 31         Iris-setosa
# 64     Iris-versicolor
# 141     Iris-virginica
# 68     Iris-versicolor
# 82     Iris-versicolor
# 110     Iris-virginica
# 12         Iris-setosa
# 36         Iris-setosa
# 9          Iris-setosa
# 19         Iris-setosa
# 56     Iris-versicolor
# 104     Iris-virginica
# 69     Iris-versicolor
# 55     Iris-versicolor
# 132     Iris-virginica
# 29         Iris-setosa
# 127     Iris-virginica
# 26         Iris-setosa
# 128     Iris-virginica
# 131     Iris-virginica
# 145     Iris-virginica
# 108     Iris-virginica
# 143     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# 22         Iris-setosa
# 15         Iris-setosa
# 65     Iris-versicolor
# 11         Iris-setosa
# 42         Iris-setosa
# 146     Iris-virginica
# 51     Iris-versicolor
# 27         Iris-setosa
# 4          Iris-setosa
# 32         Iris-setosa
# ...

# %%
#Next process is normalisation
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.3100623 , -0.49582097,  0.48403749, -0.05143998],
#        [-0.17225683,  1.92563026, -1.26851205, -1.26670948],
#        [ 2.23933883, -0.98011121,  1.76924049,  1.43388941],
#        [ 0.18948252, -0.25367584,  0.36720086,  0.35364985],
#        [ 1.15412078, -0.49582097,  0.54245581,  0.21861991],
#        [-0.53399618,  0.95704977, -1.38534869, -1.13167953],
#        [-0.29283662, -0.25367584, -0.15856401,  0.08358997],
#        [ 1.27470056,  0.2306144 ,  0.71771076,  1.43388941],
#        [ 0.43064208, -1.9486917 ,  0.36720086,  0.35364985],
#        [-0.05167705, -0.73796609,  0.01669095, -0.05143998],
#        [ 0.79238143,  0.47275953,  0.71771076,  1.02879957],
#        [-1.25747488, -0.01153072, -1.443767  , -1.53676936],
#        [-0.4134164 ,  1.19919489, -1.50218532, -1.40173942],
#        [-1.1368951 ,  0.2306144 , -1.38534869, -1.53676936],
#        [-0.89573553,  1.92563026, -1.38534869, -1.26670948],
# ...

# %%
x_train
# Out:
# array([[-0.4134164 , -1.46440146, -0.10014569, -0.32149987],
#        [ 0.55122187, -0.49582097,  0.71771076,  0.35364985],
#        [ 0.67180165,  0.2306144 ,  0.95138404,  0.75873969],
#        [ 0.91296121, -0.01153072,  0.30878254,  0.21861991],
#        [ 1.63643991,  1.44134002,  1.30189395,  1.7039493 ],
#        [-0.17225683, -0.25367584,  0.1919459 ,  0.08358997],
#        [ 2.11875905, -0.01153072,  1.59398554,  1.16382952],
#        [-0.29283662, -0.01153072,  0.36720086,  0.35364985],
#        [-0.89573553,  1.19919489, -1.443767  , -1.40173942],
#        [ 2.23933883, -0.49582097,  1.65240385,  1.02879957],
#        [-0.05167705, -0.73796609,  0.13352758, -0.32149987],
#        [-0.77515575,  0.95704977, -1.443767  , -1.40173942],
#        [-1.01631531,  1.19919489, -1.50218532, -1.26670948],
#        [-0.89573553,  1.92563026, -1.15167541, -1.13167953],
#        [-1.01631531, -2.43298195, -0.21698232, -0.32149987],
# ...

# %%
#Next process is model creation

from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=7)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
#Here we know y_pred=y_test so just print y_test

# %%
y_test
# Out:
# 73     Iris-versicolor
# 18         Iris-setosa
# 118     Iris-virginica
# 78     Iris-versicolor
# 76     Iris-versicolor
# 31         Iris-setosa
# 64     Iris-versicolor
# 141     Iris-virginica
# 68     Iris-versicolor
# 82     Iris-versicolor
# 110     Iris-virginica
# 12         Iris-setosa
# 36         Iris-setosa
# 9          Iris-setosa
# 19         Iris-setosa
# 56     Iris-versicolor
# 104     Iris-virginica
# 69     Iris-versicolor
# 55     Iris-versicolor
# 132     Iris-virginica
# 29         Iris-setosa
# 127     Iris-virginica
# 26         Iris-setosa
# 128     Iris-virginica
# 131     Iris-virginica
# 145     Iris-virginica
# 108     Iris-virginica
# 143     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# 22         Iris-setosa
# 15         Iris-setosa
# 65     Iris-versicolor
# 11         Iris-setosa
# 42         Iris-setosa
# 146     Iris-virginica
# 51     Iris-versicolor
# 27         Iris-setosa
# 4          Iris-setosa
# 32         Iris-setosa
# ...

# %%
print(model.predict(scaler.transform([[6,3,5,7]])))
# Out:
# ['Iris-virginica']

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
#Practical method of accuracy_score
score=accuracy_score(y_test,y_pred)
score
# Out:
# 1.0

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import pickle
from sklearn.datasets import load_iris


# 1. Load iris dataset
X, y = load_iris(return_X_y=True)

# 2. Create pipeline (scaling + classifier)
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', KNeighborsClassifier(n_neighbors=7))
])

# 3. Train the pipeline
pipeline.fit(X, y)

# 4. Save the trained pipeline to a file
with open("iris.pkl", "wb") as f:
    pickle.dump(pipeline, f)

print(" Iris classifier trained and saved as iris.pkl")
# Out:
#  Iris classifier trained and saved as iris.pkl
